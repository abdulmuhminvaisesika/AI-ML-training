# %%
# Importing necessary modules
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
print(f"Training images shape: {x_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Test images shape: {x_test.shape}")
print(f"Test labels shape: {y_test.shape}")
# Out:
# Training images shape: (60000, 28, 28)
# Training labels shape: (60000,)
# Test images shape: (10000, 28, 28)
# Test labels shape: (10000,)

# %%
import matplotlib.pyplot as plt

# Show the first image
plt.imshow(x_train[0], cmap='gray')  # Display in grayscale
plt.title(f"Label: {y_train[0]}")
plt.show()

# %%
# Normalize image pixel values by dividing by 255 (grayscale)
gray_scale = 255

x_train = x_train.astype('float32') / gray_scale
x_test = x_test.astype('float32') / gray_scale

# Checking the shape of feature and target matrices
print("Feature matrix (x_train):", x_train.shape)
print("Target matrix (y_train):", y_train.shape)
print("Feature matrix (x_test):", x_test.shape)
print("Target matrix (y_test):", y_test.shape)
# Out:
# Feature matrix (x_train): (60000, 28, 28)
# Target matrix (y_train): (60000,)
# Feature matrix (x_test): (10000, 28, 28)
# Target matrix (y_test): (10000,)

# %%
# Visualizing 100 images from the training data
fig, ax = plt.subplots(10, 10)
k = 0
for i in range(10):
    for j in range(10):
        ax[i][j].imshow(x_train[k].reshape(28, 28), aspect='auto')
        k += 1
plt.show()

# %%
# Building the Sequential neural network model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='sigmoid'),  
    Dense(128, activation='sigmoid'), 
    Dense(10, activation='softmax'),  
])
# Out:
# C:\Users\abdul.muhmin\AppData\Local\anaconda3\envs\py310_env\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, 
          batch_size=2000, 
          validation_split=0.2)
# Out:
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.2118 - loss: 2.2636 - val_accuracy: 0.6658 - val_loss: 1.7835
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7152 - loss: 1.6200 - val_accuracy: 0.8022 - val_loss: 1.1020
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8029 - loss: 1.0089 - val_accuracy: 0.8543 - val_loss: 0.7096
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8462 - loss: 0.6820 - val_accuracy: 0.8793 - val_loss: 0.5279
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8724 - loss: 0.5266 - val_accuracy: 0.8952 - val_loss: 0.4322
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8895 - loss: 0.4383 - val_accuracy: 0.9047 - val_loss: 0.3743
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8993 - loss: 0.3834 - val_accuracy: 0.9121 - val_loss: 0.3368
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9076 - loss: 0.3472 - val_accuracy: 0.9158 - val_loss: 0.3098
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9142 - loss: 0.3139 - val_accuracy: 0.9208 - val_loss: 0.2878
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9194 - loss: 0.2957 - val_accuracy: 0.9240 - val_loss: 0.2718

# %%
# Evaluating the model on test data
results = model.evaluate(x_test, y_test, verbose=0)
print('Test loss, Test accuracy:', results)
# Out:
# Test loss, Test accuracy: [0.2765151560306549, 0.9240000247955322]

# %%
## Importing necessary modules
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize image pixel values by dividing by 255 (grayscale)
gray_scale = 255

x_train = x_train.astype('float32') / gray_scale
x_test = x_test.astype('float32') / gray_scale

# Checking the shape of feature and target matrices
print("Feature matrix (x_train):", x_train.shape)
print("Target matrix (y_train):", y_train.shape)
print("Feature matrix (x_test):", x_test.shape)
print("Target matrix (y_test):", y_test.shape)

# Visualizing 100 images from the training data
fig, ax = plt.subplots(10, 10)
k = 0
for i in range(10):
    for j in range(10):
        ax[i][j].imshow(x_train[k].reshape(28, 28), aspect='auto', cmap='gray')
        ax[i][j].axis('off')  # Hide axes for better visualization
        k += 1
plt.suptitle("Sample Images from MNIST Dataset", fontsize=16)
plt.show()

# Building the Sequential neural network model
model = Sequential([
    # Flatten input from 28x28 images to 784 (28*28) vector
    Flatten(input_shape=(28, 28)),
  
    # Dense layer 1 (256 neurons)
    Dense(256, activation='sigmoid'),  
  
    # Dense layer 2 (128 neurons)
    Dense(128, activation='sigmoid'), 
  
    # Output layer (10 classes)
    Dense(10, activation='softmax'),  
])

# Compiling the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Training the model with training data
history = model.fit(x_train, y_train, epochs=10, 
                    batch_size=2000, 
                    validation_split=0.2)

# Evaluating the model on test data
results = model.evaluate(x_test, y_test, verbose=0)
print('Test loss, Test accuracy:', results)

# Visualization of Training and Validation Accuracy/Loss
plt.figure(figsize=(12, 5))

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')
plt.title('Training and Validation Accuracy', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(True)

# Plotting Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()
plt.grid(True)

plt.suptitle("Model Training Performance", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Feature matrix (x_train): (60000, 28, 28)
# Target matrix (y_train): (60000,)
# Feature matrix (x_test): (10000, 28, 28)
# Target matrix (y_test): (10000,)
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.2208 - loss: 2.3156 - val_accuracy: 0.6047 - val_loss: 1.8514
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.6567 - loss: 1.6965 - val_accuracy: 0.7937 - val_loss: 1.1835
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7900 - loss: 1.0849 - val_accuracy: 0.8521 - val_loss: 0.7538
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8437 - loss: 0.7250 - val_accuracy: 0.8785 - val_loss: 0.5490
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8721 - loss: 0.5431 - val_accuracy: 0.8935 - val_loss: 0.4419
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8875 - loss: 0.4494 - val_accuracy: 0.9056 - val_loss: 0.3795
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9009 - loss: 0.3855 - val_accuracy: 0.9101 - val_loss: 0.3402
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9074 - loss: 0.3500 - val_accuracy: 0.9168 - val_loss: 0.3127
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9121 - loss: 0.3214 - val_accuracy: 0.9212 - val_loss: 0.2910
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9161 - loss: 0.3030 - val_accuracy: 0.9237 - val_loss: 0.2748
# Test loss, Test accuracy: [0.28151872754096985, 0.9217000007629395]

# %%
import tensorflow as tf
import numpy as np

# Define RMSE function
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# Sample true and predicted values
y_true = np.array([3.0, -0.5, 2.0, 7.0])
y_pred = np.array([2.5, 0.0, 2.0, 8.0])

# Compute RMSE
loss = rmse(y_true, y_pred)
print("Root Mean Squared Error (RMSE):", loss.numpy())
# Out:
# Root Mean Squared Error (RMSE): 0.6123724356957945

# %%
import tensorflow as tf

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0  # Normalize

# Build a simple neural network
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')  
])

# Compile model with RMSprop optimizer
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8832 - loss: 0.4104 - val_accuracy: 0.9562 - val_loss: 0.1460
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9629 - loss: 0.1295 - val_accuracy: 0.9734 - val_loss: 0.0909
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9750 - loss: 0.0857 - val_accuracy: 0.9711 - val_loss: 0.0974
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9808 - loss: 0.0656 - val_accuracy: 0.9745 - val_loss: 0.0866
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9835 - loss: 0.0544 - val_accuracy: 0.9768 - val_loss: 0.0854
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9869 - loss: 0.0476 - val_accuracy: 0.9779 - val_loss: 0.0827
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9889 - loss: 0.0390 - val_accuracy: 0.9771 - val_loss: 0.0868
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9904 - loss: 0.0321 - val_accuracy: 0.9769 - val_loss: 0.0896
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9928 - loss: 0.0271 - val_accuracy: 0.9772 - val_loss: 0.0956
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9931 - loss: 0.0244 - val_accuracy: 0.9748 - val_loss: 0.0993

# %%
import torch 
x = torch.tensor([1.0, 2.0, 3.0])
print(x)
# Out:
# tensor([1., 2., 3.])

# %%
x = torch.tensor(2.0 , requires_grad = True)
y = x ** 2
y.backward()
print(x.grad)
# Out:
# tensor(4.)

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
# Out:
# -------------------------------------------------------------
# AttributeError              Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
#
# AttributeError: 'Sequential' object has no attribute 'parameters'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# %%
train_dataset = torchvision.datasets.MNIST( root = './data', train = True, transform = transforms.ToTensor(), download = True)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size =32, shuffle =True)
print(train_dataset)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()
    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model = SimpleNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)

for epoch in range(5):
    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 0.359431654214859
# Epoch 2, Loss: 0.07739517837762833
# Epoch 3, Loss: 0.15773384273052216
# Epoch 4, Loss: 0.047375090420246124
# Epoch 5, Loss: 0.09309632331132889

# %%
def predict(model, image):
    image = image.view(-1, 28*28)
    output = model(image)
    _, predicted_label = torch.max(output, 1)
    return predicted_label

# Test a sample
sample_image, sample_label = train_dataset[0]
print(f"Predicted Label: {predict(model, sample_image)}")
print(f"Actual Label: {sample_label}")
# Out:
# Predicted Label: tensor([5])
# Actual Label: 5

# %%
import torch
x = torch.tensor([1.0, 2.0, 3.0])
x
# Out:
# tensor([1., 2., 3.])

# %%
a= torch.tensor([3.0])
b= torch.tensor([5.0])
c = a + b
c
# Out:
# tensor([8.])

# %%
rand_tensor = torch.randn(3,3)
rand_tensor
# Out:
# tensor([[-0.4957,  1.3096, -0.0813],
#         [-1.1572, -1.4260, -1.5040],
#         [-0.8480,  0.2689, -0.0455]])

# %%
import numpy as np
np_array = np.array([1,2,3])
tensor = torch.from_numpy(np_array)
tensor
# Out:
# tensor([1, 2, 3])

# %%
x = torch.tensor(2.0, requires_grad = True)
y = x ** 3
y.backward()
print(x.grad)
# Out:
# tensor(12.)

# %%
model = torch.nn.Linear(2,1)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)  # SGD optimizer

# %%
criterion = torch.nn.MSELoss()
y_pred = torch.tensor([3.0], requires_grad =True)
y_true = torch.tensor([2.0])
loss = criterion(y_pred, y_true)
print(loss)
# Out:
# tensor(1., grad_fn=<MseLossBackward0>)

# %%
from torch.utils.data import DataLoader, TensorDataset

# Sample dataset (features and labels)
features = torch.tensor([[1.0], [2.0], [3.0]])
labels = torch.tensor([[2.0], [4.0], [6.0]])

dataset = TensorDataset(features, labels)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

for batch in dataloader:
    print(batch)
# Out:
# [tensor([[2.],
#         [1.]]), tensor([[4.],
#         [2.]])]
# [tensor([[3.]]), tensor([[6.]])]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# %%
train_dataset = torchvision.datasets.MNIST(root = './data', train = True, transform = transforms.ToTensor(), download = True)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size =32, shuffle = True)

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__() #calls the parent class (nn.Module) constuctor
        self.fc1 = nn.Linear(28*28, 128) #flattened images(28*28 = 784pixels) as input and maps tp0 128 neurons
        self.fc2 = nn.Linear(128, 10) #scecond layer maps 128 neurons to 10 outpur classes(0-9 digits)
        
        self.relu = nn.ReLU() #add non-linearity
    def forward(self, x):
        x = x.view(-1, 28*28) #reshapes into 1D bc pytorch expects 1D vector ,not 2D image
        x = self.relu(self.fc1(x)) #apply ReLU activation to introduce non-linearity
        x = self.fc2(x)
        return x

# %%
model = SimpleNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr =0.001)

# %%
for epoch in range(5):
    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss :{loss.item()}")
# Out:
# Epoch 1, Loss :0.12545539438724518
# Epoch 2, Loss :0.027917001396417618
# Epoch 3, Loss :0.05135805532336235
# Epoch 4, Loss :0.015431509353220463
# Epoch 5, Loss :0.0024347961880266666

# %%
import torch.nn as nn
embedding = nn.Embedding(num_embeddings=5000, embedding_dim= 300)
embedding
# Out:
# Embedding(5000, 300)

# %%
from torch.nn.utils.rnn import pad_sequence

# %%
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
