# %%
from typing import Annotated

from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.messages import BaseMessage
from typing_extensions import TypedDict
from langchain_community.chat_models import ChatOllama

from langgraph.graph import StateGraph
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition

# %%
import os
os.environ["TAVILY_API_KEY"] = "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"

# %%
class State(TypedDict):
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)


tool = TavilySearchResults(max_results=2)
tools = [tool]

llm = ChatOllama(model="mistral")
llm_with_tools = llm.bind_tools(tools)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[16], line 12
#       9 tools = [tool]
#      11 llm = ChatOllama(model="mistral")
# ---> 12 llm_with_tools = llm.bind_tools(tools)
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1273, in BaseChatModel.bind_tools(self, tools, tool_choice, **kwargs)
#    1255 def bind_tools(
#    1256     self,
#    1257     tools: Sequence[
#    (...)   1262     **kwargs: Any,
#    1263 ) -> Runnable[LanguageModelInput, BaseMessage]:
#    1264     """Bind tools to the model.
#    1265
#    1266     Args:
#    (...)   1271         A Runnable that returns a message.
#    1272     """
# -> 1273     raise NotImplementedError
#
# NotImplementedError:

# %%
def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder.add_node("chatbot", chatbot)

tool_node = ToolNode(tools=[tool])
graph_builder.add_node("tools", tool_node)

graph_builder.add_conditional_edges(
    "chatbot",
    tools_condition,
)
# Any time a tool is called, we return to the chatbot to decide the next step
graph_builder.add_edge("tools", "chatbot")
graph_builder.set_entry_point("chatbot")
graph = graph_builder.compile()

# %%
from langchain_core.messages import HumanMessage

inputs = {
    "messages": [HumanMessage(content="Who is the CEO of OpenAI?")]
}

async def run_chatbot():
    async for step in graph.astream(inputs):
        print(step)

await run_chatbot()
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[12], line 11
#       8     async for step in graph.astream(inputs):
#       9         print(step)
# ---> 11 await run_chatbot()
#
# Cell In[12], line 8, in run_chatbot()
#       7 async def run_chatbot():
# ----> 8     async for step in graph.astream(inputs):
#       9         print(step)
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langgraph\pregel\__init__.py:2626, in Pregel.astream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2620 # Similarly to Bulk Synchronous Parallel / Pregel model
#    2621 # computation proceeds in steps, while there are channel updates
#    2622 # channel updates from step N are only visible in step N+1
#    2623 # channels are guaranteed to be immutable for the duration of the step,
#    2624 # with channel updates applied only at the transition between steps
#    2625 while loop.tick(input_keys=self.input_channels):
# -> 2626     async for _ in runner.atick(
#    2627         loop.tasks.values(),
#    2628         timeout=self.step_timeout,
#    2629         retry_policy=self.retry_policy,
#    2630         get_waiter=get_waiter,
#    2631     ):
#    2632         # emit output
#    2633         for o in output():
#    2634             yield o
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langgraph\pregel\runner.py:288, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     286 t = tasks[0]
#     287 try:
# --> 288     await arun_with_retry(
#     289         t,
#     290         retry_policy,
#     291         stream=self.use_astream,
#     292         configurable={
#     293             CONFIG_KEY_CALL: partial(
#     294                 _acall,
#     295                 weakref.ref(t),
#     296                 stream=self.use_astream,
#     297                 retry=retry_policy,
#     298                 futures=weakref.ref(futures),
#     299                 schedule_task=self.schedule_task,
#     300                 submit=self.submit,
#     301                 reraise=reraise,
#     302                 loop=loop,
#     303             ),
#     304         },
#     305     )
#     306     self.commit(t, None)
#     307 except Exception as exc:
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langgraph\pregel\retry.py:128, in arun_with_retry(task, retry_policy, stream, configurable)
#     126         break
#     127     else:
# --> 128         return await task.proc.ainvoke(task.input, config)
#     129 except ParentCommand as exc:
#     130     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langgraph\utils\runnable.py:643, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     639 config = patch_config(
#     640     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     641 )
#     642 if i == 0:
# --> 643     input = await step.ainvoke(input, config, **kwargs)
#     644 else:
#     645     input = await step.ainvoke(input, config)
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langgraph\utils\runnable.py:431, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     429 if ASYNCIO_ACCEPTS_CONTEXT:
#     430     coro = cast(Coroutine[None, None, Any], self.afunc(*args, **kwargs))
# --> 431     ret = await asyncio.create_task(coro, context=context)
#     432 else:
#     433     ret = await self.afunc(*args, **kwargs)
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langchain_core\runnables\config.py:616, in run_in_executor(executor_or_config, func, *args, **kwargs)
#     612         raise RuntimeError from exc
#     614 if executor_or_config is None or isinstance(executor_or_config, dict):
#     615     # Use default executor with context copied from current context
# --> 616     return await asyncio.get_running_loop().run_in_executor(
#     617         None,
#     618         cast("Callable[..., T]", partial(copy_context().run, wrapper)),
#     619     )
#     621 return await asyncio.get_running_loop().run_in_executor(executor_or_config, wrapper)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langchain_core\runnables\config.py:607, in run_in_executor.<locals>.wrapper()
#     605 def wrapper() -> T:
#     606     try:
# --> 607         return func(*args, **kwargs)
#     608     except StopIteration as exc:
#     609         # StopIteration can't be set on an asyncio.Future
#     610         # it raises a TypeError and leaves the Future pending forever
#     611         # so we need to convert it to a RuntimeError
#     612         raise RuntimeError from exc
#
# Cell In[10], line 2, in chatbot(state)
#       1 def chatbot(state: State):
# ----> 2     return {"messages": [llm_with_tools.invoke(state["messages"])]}
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langchain_core\runnables\base.py:5440, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5433 @override
#    5434 def invoke(
#    5435     self,
#    (...)   5438     **kwargs: Optional[Any],
#    5439 ) -> Output:
# -> 5440     return self.bound.invoke(
#    5441         input,
#    5442         self._merge_configs(config),
#    5443         **{**self.kwargs, **kwargs},
#    5444     )
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:331, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     319 @override
#     320 def invoke(
#     321     self,
#    (...)    326     **kwargs: Any,
#     327 ) -> BaseMessage:
#     328     config = ensure_config(config)
#     329     return cast(
#     330         "ChatGeneration",
# --> 331         self.generate_prompt(
#     332             [self._convert_input(input)],
#     333             stop=stop,
#     334             callbacks=config.get("callbacks"),
#     335             tags=config.get("tags"),
#     336             metadata=config.get("metadata"),
#     337             run_name=config.get("run_name"),
#     338             run_id=config.pop("run_id", None),
#     339             **kwargs,
#     340         ).generations[0][0],
#     341     ).message
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:894, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     885 @override
#     886 def generate_prompt(
#     887     self,
#    (...)    891     **kwargs: Any,
#     892 ) -> LLMResult:
#     893     prompt_messages = [p.to_messages() for p in prompts]
# --> 894     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:719, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     716 for i, m in enumerate(messages):
#     717     try:
#     718         results.append(
# --> 719             self._generate_with_cache(
#     720                 m,
#     721                 stop=stop,
#     722                 run_manager=run_managers[i] if run_managers else None,
#     723                 **kwargs,
#     724             )
#     725         )
#     726     except BaseException as e:
#     727         if run_managers:
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:960, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     958 else:
#     959     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 960         result = self._generate(
#     961             messages, stop=stop, run_manager=run_manager, **kwargs
#     962         )
#     963     else:
#     964         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\langchain_anthropic\chat_models.py:1102, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1100     return generate_from_stream(stream_iter)
#    1101 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# -> 1102 data = self._client.messages.create(**payload)
#    1103 return self._format_output(data, **kwargs)
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\anthropic\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\anthropic\resources\messages\messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     946 if model in DEPRECATED_MODELS:
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\anthropic\_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1322 def post(
#    1323     self,
#    1324     path: str,
#    (...)   1331     stream_cls: type[_StreamT] | None = None,
#    1332 ) -> ResponseT | _StreamT:
#    1333     opts = FinalRequestOptions.construct(
#    1334         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335     )
# -> 1336     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\anthropic\_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010 else:
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File c:\Users\abdul.muhmin\Al&ML\local_ai_agent\LocalAIAgentWithRAG\Restaurant Review AI Agent\venv\Lib\site-packages\anthropic\_base_client.py:1117, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1114         err.response.read()
#    1116     log.debug("Re-raising status error")
# -> 1117     raise self._make_status_error_from_response(err.response) from None
#    1119 return self._process_response(
#    1120     cast_to=cast_to,
#    1121     options=options,
#    (...)   1125     retries_taken=retries_taken,
#    1126 )
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}}
# During task with name 'chatbot' and id '3d2242aa-ba45-0bcd-76b0-3523669833fa'

# %%
# %pip install anthropic
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: anthropic in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (0.49.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from anthropic) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from anthropic) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from anthropic) (2.11.1)
# Requirement already satisfied: sniffio in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: idna>=2.8 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from httpx<1,>=0.23.0->anthropic) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from httpx<1,>=0.23.0->anthropic) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\abdul.muhmin\al&ml\local_ai_agent\localaiagentwithrag\restaurant review ai agent\venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
